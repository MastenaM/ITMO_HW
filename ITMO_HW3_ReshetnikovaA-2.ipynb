# %% [markdown]
# # Считайте датасет из файла train.csv (это данные о выживаемости на Титанике) - 1 балл

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
name_of_file='train.csv'
path = '/content/drive/My Drive/Colab Notebooks/'+ name_of_file

# %%
import pandas as pd

# %%
df = pd.read_csv(path)

# %% [markdown]
# # Выведите основную информацию о датасете: информацию о типах данных, число пропусков, средние значения и т.д. - 1 балл

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [raw]
# Выведите основную информацию о датасете: информацию о типах данных, число пропусков, средние значения и т.д.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # Посчитайте процент выживаемости у каждого класса пассажиров (Pclass) - 1 балл

# %%
total_class1 = len(df[df['Pclass'] == 1])
total_class2 = len(df[df['Pclass'] == 2])
total_class3 = len(df[df['Pclass'] == 3])
survived_class1 = len(df[(df['Pclass'] == 1) & (df['Survived'] == 1)])
survived_class2 = len(df[(df['Pclass'] == 2) & (df['Survived'] == 1)])
survived_class3 = len(df[(df['Pclass'] == 3) & (df['Survived'] == 1)])
rate_surv1 = survived_class1*100/total_class1
rate_surv2 = survived_class2*100/total_class2
rate_surv3 = survived_class3*100/total_class3
print(rate_surv1)
print(rate_surv2)
print(rate_surv3)
# Out:
# 62.96296296296296
# 47.28260869565217
# 24.236252545824847

# %% [raw]
# # Выведите самое популярное мужское и самое популярное женское имя на корабле

# %%
#df[df['Name'] == Mrs.].head()

# %%
df[['Surname','Name']] = df['Name'].str.split(",",expand=True)

# %%
df.head(3) #получили разделение столбцов имени и фамилии
# Out:
#    PassengerId  Survived  Pclass                                         Name  \
# 0            1         0       3                              Mr. Owen Harris
# 1            2         1       1   Mrs. John Bradley (Florence Briggs Thayer)
# 2            3         1       3                                  Miss. Laina
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
#
#      Surname
# 0     Braund
# 1    Cumings
# 2  Heikkinen

# %%
#Теперь нам нужно разделить имена на несколько столбцов

# %%
df['Name'] = df['Name'].str.replace(' ', '', n=1)
df['Name'].head(3)
# Out:
# 0                               Mr. Owen Harris
# 1    Mrs. John Bradley (Florence Briggs Thayer)
# 2                                   Miss. Laina
# Name: Name, dtype: object

# %%
df[['Appeal','Name','Name2','OtherPartofName']] = df['Name'].str.split(' ', expand=True, n=3)
df.head(5)
# Out:
#    PassengerId  Survived  Pclass     Name     Sex   Age  SibSp  Parch  \
# 0            1         0       3     Owen    male  22.0      1      0
# 1            2         1       1     John  female  38.0      1      0
# 2            3         1       3    Laina  female  26.0      0      0
# 3            4         1       1  Jacques  female  35.0      1      0
# 4            5         0       3  William    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked    Surname Appeal    Name2  \
# 0         A/5 21171   7.2500   NaN        S     Braund    Mr.   Harris
# 1          PC 17599  71.2833   C85        C    Cumings   Mrs.  Bradley
# 2  STON/O2. 3101282   7.9250   NaN        S  Heikkinen  Miss.     None
# 3            113803  53.1000  C123        S   Futrelle   Mrs.    Heath
# 4            373450   8.0500   NaN        S      Allen    Mr.    Henry
#
#             OtherPartofName
# 0                      None
# 1  (Florence Briggs Thayer)
# 2                      None
# ...

# %%
#Теперь для женщин, которые замужем, в столбцах с именами указаны имена их мужей, а в столбце с другой частью имени их собственные.
#Нужно это исправить, перенеся их имена в столбцы с именами

# %%
def replace_names(row):
    if row['Appeal'] == 'Mrs.':
        other_part_name = row['OtherPartofName']
        if other_part_name:
            parts = other_part_name.strip('()').split(' ')
            if len(parts) >= 2:
                row['Name'] = parts[0]
                row['Name2'] = parts[1]
    return row

df = df.apply(replace_names, axis=1)
df.head(10)
# Out:
#    PassengerId  Survived  Pclass       Name     Sex   Age  SibSp  Parch  \
# 0            1         0       3       Owen    male  22.0      1      0
# 1            2         1       1   Florence  female  38.0      1      0
# 2            3         1       3      Laina  female  26.0      0      0
# 3            4         1       1       Lily  female  35.0      1      0
# 4            5         0       3    William    male  35.0      0      0
# 5            6         0       3      James    male   NaN      0      0
# 6            7         0       1    Timothy    male  54.0      0      0
# 7            8         0       3      Gosta    male   2.0      3      1
# 8            9         1       3  Elisabeth  female  27.0      0      2
# 9           10         1       2   Nicholas  female  14.0      1      0
#
#              Ticket     Fare Cabin Embarked    Surname   Appeal       Name2  \
# 0         A/5 21171   7.2500   NaN        S     Braund      Mr.      Harris
# ...

# %% [markdown]
# ## топ по столбцу Name (по первому имени)
# топ мужских имен по первому имени

# %%
male_names = df[df['Sex'] == 'male']

male_name1_most = male_names['Name'].mode()[0]
male_name1_most
# Out:
# 'William'

# %%
top_male_names1 = male_names['Name'].value_counts(sort=True)
top_male_names1.head(10)
# Out:
# Name
# William    35
# John       25
# George     14
# Charles    13
# Thomas     13
# Henry      12
# James      11
# Richard    10
# Johan       9
# Edward      9
# Name: count, dtype: int64

# %% [markdown]
# топ женских имен по первому имени

# %%
female_names = df[df['Sex'] == 'female']
female_name1_most = female_names['Name'].mode()[0]
female_name1_most
# Out:
# 'Anna'

# %%
top_female_names1 = female_names['Name'].value_counts(sort=True)
top_female_names1.head(10)
# Out:
# Name
# Anna         12
# Mary         12
# Margaret      8
# Alice         7
# Elizabeth     6
# Helen         5
# Marie         5
# Bertha        5
# Ellen         4
# Kate          4
# Name: count, dtype: int64

# %% [markdown]
# ## топ по столбцу Name2 (второе имя).
# Для этого первым делом приводим в чистый вид

# %%
df['Name2'] = df['Name2'].str.replace('[( )"]', '', regex=True)
df['Name2']
# Out:
# 0      Harris
# 1      Briggs
# 2        None
# 3         May
# 4       Henry
#         ...
# 886      None
# 887     Edith
# 888     Helen
# 889    Howell
# 890      None
# Name: Name2, Length: 891, dtype: object

# %% [markdown]
# топ мужских имен по второму имени

# %%
male_name2_most = male_names['Name2'].mode()[0]
male_name2_most
# Out:
# 'Henry'

# %%
top_male_names2 = male_names['Name2'].value_counts(sort=True)
top_male_names2.head(10)
# Out:
# Name2
# Henry      15
# William    11
# John       10
# James       9
# J           7
# George      6
# H           6
# Charles     6
# Edward      5
# Leonard     5
# Name: count, dtype: int64

# %% [markdown]
# топ женских имен по второму имени

# %%
female_name2_most = female_names['Name2'].mode()[0]
female_name2_most
# Out:
# 'Sofia'

# %%
top_female_names2 = female_names['Name2'].value_counts(sort=True)
top_female_names2.head(10)
# Out:
# Name2
# Sofia        6
# Mary         4
# E            4
# Edith        3
# Maria        3
# Louise       3
# Elizabeth    3
# Walton       3
# (Maria       2
# "Katie"      2
# Name: count, dtype: int64

# %% [markdown]
# ## топ по всем  именам
# топ по всем мужским именам

# %%
all_male_names = top_male_names1.add(top_male_names2, fill_value=0)
top_male_names = all_male_names.sort_values(ascending=False)
top_male_names.head(10)
# Out:
# William    46.0
# John       35.0
# Henry      27.0
# James      20.0
# George     20.0
# Charles    19.0
# Thomas     15.0
# Edward     14.0
# Johan      13.0
# Richard    12.0
# Name: count, dtype: float64

# %% [markdown]
# топ по всем женским именам

# %%
all_female_names = top_female_names1.add(top_female_names2, fill_value=0)
top_female_names = all_female_names.sort_values(ascending=False)
top_female_names.head(10)
# Out:
# Mary         16.0
# Anna         14.0
# Margaret     10.0
# Elizabeth     9.0
# Alice         8.0
# Helen         7.0
# Sofia         6.0
# Maria         6.0
# Marie         6.0
# Bertha        5.0
# Name: count, dtype: float64

# %% [raw]
# # Выведите самое популярное мужское и самое популярное женское имя на корабле в каждом классе

# %%
popular_names_class = df.groupby(['Pclass', 'Sex'])['Name'].agg(lambda x: x.value_counts().idxmax())
popular_names_class
# Out:
# Pclass  Sex
# 1       female    Margaret
#         male       William
# 2       female         Ada
#         male       William
# 3       female        Anna
#         male       William
# Name: Name, dtype: object

# %%
popular_names2_class = df.groupby(['Pclass', 'Sex'])['Name2'].agg(lambda x: x.value_counts().idxmax())
popular_names2_class
# Out:
# Pclass  Sex
# 1       female    Edith
#         male          H
# 2       female     Mary
#         male      James
# 3       female    Sofia
#         male      Henry
# Name: Name2, dtype: object

# %% [raw]
# # Выведите часть таблицы с пассажирами, возраст которых больше 44 лет

# %%
passangers_over_44 = df[df['Age'] > 44]
passangers_over_44
# Out:
#      PassengerId  Survived  Pclass       Name     Sex   Age  SibSp  Parch  \
# 6              7         0       1    Timothy    male  54.0      0      0
# 11            12         1       1  Elizabeth  female  58.0      0      0
# 15            16         1       2  Kingcome)  female  55.0      0      0
# 33            34         0       2     Edward    male  66.0      0      0
# 52            53         1       1       Myna  female  49.0      1      0
# ..           ...       ...     ...        ...     ...   ...    ...    ...
# 857          858         1       1      Peter    male  51.0      0      0
# 862          863         1       1   Margaret  female  48.0      0      0
# 871          872         1       1     Sallie  female  47.0      1      1
# 873          874         0       3     Victor    male  47.0      0      0
# 879          880         1       1       Lily  female  56.0      0      1
#
#          Ticket     Fare Cabin Embarked          Surname Appeal     Name2  \
# ...

# %% [raw]
# # Выведите часть таблицы с пассажирами, возраст которых меньше 44 лет и которые мужского пола

# %%
men_under_44 = df[(df['Sex'] == 'male') & (df['Age'] < 44)]
men_under_44
# Out:
#      PassengerId  Survived  Pclass       Name   Sex   Age  SibSp  Parch  \
# 0              1         0       3       Owen  male  22.0      1      0
# 4              5         0       3    William  male  35.0      0      0
# 7              8         0       3      Gosta  male   2.0      3      1
# 12            13         0       3    William  male  20.0      0      0
# 13            14         0       3     Anders  male  39.0      1      5
# ..           ...       ...     ...        ...   ...   ...    ...    ...
# 883          884         0       2  Frederick  male  28.0      0      0
# 884          885         0       3      Henry  male  25.0      0      0
# 886          887         0       2     Juozas  male  27.0      0      0
# 889          890         1       1       Karl  male  26.0      0      0
# 890          891         0       3    Patrick  male  32.0      0      0
#
#                Ticket    Fare Cabin Embarked      Surname   Appeal    Name2  \
# ...

# %% [raw]
# # Выведите количества n-местных кабин (в которых было 2, 3, 4, ... человека)

# %%
cabin_counts = df.groupby('Cabin')['PassengerId'].count()
cabin_counts
# Out:
# Cabin
# A10    1
# A14    1
# A16    1
# A19    1
# A20    1
#       ..
# F33    3
# F38    1
# F4     2
# G6     4
# T      1
# Name: PassengerId, Length: 147, dtype: int64

# %%
n_place_counts = cabin_counts.value_counts().sort_index()
n_place_counts #PassengerId выступает за количество человек
# Out:
# PassengerId
# 1    101
# 2     38
# 3      5
# 4      3
# Name: count, dtype: int64
